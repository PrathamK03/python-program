# %%
x=2
print(type(x))
x=3.5
print(x)
const(x)

# %%
import constant
a=3.4
print(a)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-cd57990e5d96> in <cell line: 1>()
# ----> 1 import constant
#       2 a=3.4
#       3 print(a)
#
# ModuleNotFoundError: No module named 'constant'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
pip install constant

# %%
import constant
a = 3.4
print(constant.a)
a=5.6
print(a)

# %%
a=1
b=2
c=3
c=a+b+c
print(c)
c+=a
print(c)
c*=b
print(c)
c=c+1
print(c)
c=c-1
print(c)
# Out:
# 6
# 7
# 14
# 15
# 14

# %%
x={"avinash","balloon","cat"}
print(x)
# Out:
# {'cat', 'avinash', 'balloon'}

# %%
tuple1=('a','b','cat','d','1.2','2.4')
print(tuple1)
# Out:
# ('a', 'b', 'cat', 'd', '1.2', '2.4')

# %%
array1=['a','b','cat',"1.5","2.2"]
print(array1)
# Out:
# ['a', 'b', 'cat', '1.5', '2.2']

# %%
dict1={
  'roll_no':('1','2','3'),
  'name':['a','b','c'],
  'age':{'10','20','30'}
  }
print(dict1)
# Out:
# {'roll_no': ('1', '2', '3'), 'name': ['a', 'b', 'c'], 'age': {'20', '30', '10'}}

# %%
dept={
    'teach':{
        'employ_id':('1','2','3'),
        'name':('a','b','c'),
        'mob_no':('123','456','789')
    },
    'non_teach':{
        'employ_id':('4','5','6'),
        'name':('d','e','f'),
        'mob_no':('101112','121415','161718')
    }
}
print(dept)
# Out:
# {'teach': {'employ_id': ('1', '2', '3'), 'name': ('a', 'b', 'c'), 'mob_no': ('123', '456', '789')}, 'non_teach': {'employ_id': ('4', '5', '6'), 'name': ('d', 'e', 'f'), 'mob_no': ('101112', '121415', '161718')}}

# %%
x=('a','b','c','d','e','f','g','h','i','j','k','l')
for x in range(3,10):
  print(x)
# Out:
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
a=int(input('enter value of a '))
b=int(input('enter value of b '))
c=int(input('enter value of c '))
if (a>b) & (a>c):
  {
    print("a is greatest")
  }
elif (b>c) & (b>a):
  {
    print("b is greatest")
  }
elif (c>a) & (c>b):
  {
    print("c is greatest")
  }
else:
  {
    print("all are equal")
  }
# Out:
# enter value of a5
# enter value of b3
# enter value of c9
# c is greatest

# %%
def operations(num):
  switch={
      1 : "Vowel",
      2 : "Vowel",
      3 : "Vowel",
      4 : "Vowel",
      5 : "Vowel",
  }
  return switch.get(num,"It is not a vowel")
print(operations(1))
# Out:
# Vowel

# %%
def operations(num):
  switch={
      1 : "One",
      2 : "Two",
      3 : "Three",
      4 : "Four",
  }
  return switch.get(num,"It is not a number")
print(operations(2))
# Out:
# Two

# %%
number = -2

if number > 0:
    print('Number is positive.')
else:
    print('Number is negative.')
# Out:
# Number is negative.

# %%
number = 0

if number > 0:
    print("Positive number")
elif number == 0:
    print('Zero')
else:
    print('Negative number')
# Out:
# Zero

# %%
# Addition:

a=10
b=5
def add (a: int,b: int):
  c=a+b
  print(c)
add(a,b)
# Out:
# 15

# %%
# Factorial:

num=int(input("Enter a number:"))
fact=1
if(num==0):
  print("Error")
elif(num==1):
  print("Factorial is 1")
else:
  for i in range(1,num+1):
    fact=fact*i
print(fact)
# Out:
# Enter a number:3
# 6

# %%
# Fibbonacci:

count=0
terms=5
a=0
b=a+1
print(a)
print(b)
for i in range(count,terms+1):
  c=a+b
  print(c)
  a=b
  b=c
  count+=1
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13

# %%
num=int(input("Enter a number:"))
def fact(num:int):
  fact=1
  if(num==0):
    print("Error")
  elif(num==1):
    print("Factorial is 1")
  else:
    for i in range(1,num+1):
      fact=fact*i
  print(fact)
fact(num)
# Out:
# Enter a number:3
# 6

# %%
def fib(a:int,b:int):
  count=0
  terms=5
  a=0
  b=a+1
  print(a)
  print(b)
  for i in range(count,terms+1):
   c=a+b
  print(c)
  a=b
  b=c
  count+=1
fib(a,b)
# Out:
# 0
# 1
# 1

# %%
def leap(num):
  num=int(input("Enter year:"))
  if(num%4==0):
    print("leap year")
  else:
    print("not a leap year")
leap(num)
# Out:
# Enter year:2020
# leap year

# %%
print("hello world")
# Out:
# hello world

# %%
n1=int(input('enter 1st number:'))
n2=int(input('enter 2nd number:'))
add=n1+n2
print('your total sum is:')
print(add)
# Out:
# enter 1st number:2

# %%
n=int(input('enter a number:'))
if(n%2==0):
  print('number is even')
else:
  print('number is odd')

# %%
p=float(input('enter initial principal balance:'))
r=float(input('enter interest rate:'))
n=float(input('enter number of times interest applied per time period:'))
t=float(input('enter number of time periods elapsed:'))
a=p*(pow((1+r/n), n*t))
print('compound interest is:')
print(a)

# %%
x="12345543"
print(x.capitalize())
print(x.title())
print(x.upper())
print(x.lower())
print(x.swapcase())
y=int(x.count('a'))
print(y)
print(x.isdigit())

# %%
def user():

  arr1=[]
  n=int(input('enter the number of elements in an array:'))
  for i in range(0,n):
    arr=int(input())
    arr1.append(arr)
  print(arr1)
def add():
  l=len(arr1)+1
  sum=0
  for i in range(l):
    sum=sum+i
  print(sum)
user()
add()

# %%
x=[1,2,3,4]
l=len(x)+1
sum=0
for i in range(l):
  sum=sum+i
  sum1=sum+sum
print(sum1)

# %%
array2=[]
n=int(input('enter elements:'))
for i in range(0,n):
  array1=int(input())
  array2.append(array1)
print(array2)
# Out:
# enter elements:4
# 1
# 2
# 3
# 4
# [1, 2, 3, 4]

# %%
num = int(input('enter a number:'))
for i in range(0, 11):
  print(num,'x',i,'=',num * i)

# %%
value=(input('enter an alphabet:'))
ord('value')

# %%
# !pip install Point
# !pip install point
# !pip install distance
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for Point: filename=point-0.0.1-py3-none-any.whl size=1676 sha256=9d06d148876457123eeafd30fc29092f320cb7c63e515a043cc59751bf15680a
#   Stored in directory: /root/.cache/pip/wheels/d6/f2/71/555df6f070640944015630065118e27e4003f5a5abfdc6a5c8
# Successfully built Point
# ...
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# ...

# %%
import math

def distance(p1,p2):
  dx=p1.x-p2.x
  dy=p1.y-p2.y
  d2=dx*dx+dy*dy
  return math.sqrt(d2)

class Point:
  def __init__(self,x,y):
    self.x=x
    self.y=y

  def move(self,dx,dy):
    self.x+=dx
    self.y+=dy

# %%
from point import Point,distance

p1=Point(3,0)
p2=Point(0,3)
p2.move(0,1)
d=distance(p1,p2)
print(d)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-c9d640eafb12> in <cell line: 1>()
# ----> 1 from point import Point,distance
#       2
#       3 p1=Point(3,0)
#       4 p2=Point(0,3)
#       5 p2.move(0,1)
#
# ImportError: cannot import name 'Point' from 'point' (/usr/local/lib/python3.10/dist-packages/point/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from pathlib import Path

def count_lines(filename):
  path=Path(filename)
  txt=path.read_text()
  lines=txt.split('\n')
  return len(lines)
n_lines=count_lines('spam.txt'))
print('number of lines: {n_lines}')

# %%
def add(a,b):
return a+b
# Out:
#   File "<ipython-input-6-f8fbd26b172b>", line 2
#     return a+b
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
'spam' ==='ham'
# Out:
#   File "<ipython-input-7-cd3d876b6d3c>", line 1
#     'spam' ==='ham'
#              ^
# SyntaxError: invalid syntax

# %%
println('hello world')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-04c55cba6a44> in <cell line: 1>()
# ----> 1 println('hello world')
#
# NameError: name 'println' is not defined

# %%
conferences=['pycon' 'pydata']
conferences.copi()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-260aa2f3582a> in <cell line: 2>()
#       1 conferences=['pycon' 'pydata']
# ----> 2 conferences.copi()
#
# AttributeError: 'list' object has no attribute 'copi'

# %%
conferences[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-c9b1d6ff2089> in <cell line: 1>()
# ----> 1 conferences[1]
#
# IndexError: list index out of range

# %%
python_skills={'guide':8,'christoph':3}
python_skills['gido']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-b1adb76b028e> in <cell line: 2>()
#       1 python_skills={'guide':8,'christoph':3}
# ----> 2 python_skills['gido']
#
# KeyError: 'gido'

# %%
a,b=1,0
try:
  result=a/b
except ZeroDivisionError:
  result=c

print(f'Result:{result}')

# %%
import math
def distance(p1,p2):
  dx=p1.x-p2.x
  dy=p1.y-p2.y
  d2=dx*dx+dy*dy
  return math.sqrt(d2)

  class Point:
    def __init__(self,x,y):
      self.x=x
      self.y=y

    def move(self,dx,dy):
      self.x+=dx
      self.y+=dy

from point import Point

def move_it(point):
  point.move(1,2)

def main():
  p=Point('10','20')
  move_it(p)

main()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-5d113fd3448c> in <cell line: 17>()
#      15       self.y+=dy
#      16
# ---> 17 from point import Point
#      18
#      19 def move_it(point):
#
# ImportError: cannot import name 'Point' from 'point' (/usr/local/lib/python3.10/dist-packages/point/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import math
def distance(p1,p2):
  dx=p1.x-p2.x
  dy=p1.y-p2.y
  d2=dx*dx+dy*dy
  return math.sqrt(d2)

  class Point:
    def __init__(self,x,y):
      self.x=x
      self.y=y

    def move(self,dx,dy):
      self.x+=dx
      self.y+=dy

# %%
from point import Point

def move_it(point):
  point.move(1,2)

def main():
  p=Point('10','20')
  move_it(p)

main()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-f8ad898c20a9> in <cell line: 1>()
# ----> 1 from point import Point
#       2
#       3 def move_it(point):
#       4   point.move(1,2)
#       5
#
# ImportError: cannot import name 'Point' from 'point' (/usr/local/lib/python3.10/dist-packages/point/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
def funcl(a,b):
  return a/b

def func2(x):
  a=x
  b=x
  return funcl(a,b)

# %%
# %mode minimal

# %%
func2(1)

# %%
# %debug

# %%
import logging
logging.basicConfig(filename='example.log',level=logging.DEBUG)
logging.debug('this message should go to the log file')
logging.info('so should this')
logging.warning('and this too')

# %%
import numpy as np
x=np.array([[1,2,3,4],[2,4,6,8]]) #array using list.
print(x)

y=np.array((1,2,3)) #array using tuples.
print(y)

print(type(x))
print(x.ndim)
print(x.size)
print(x.shape)
print(x.dtype)

x1=np.zeros((2,2))
print(x1)
x2=np.random(4)
print(x2)
# Out:
# [[1 2 3 4]
#  [2 4 6 8]]
# [1 2 3]
# <class 'numpy.ndarray'>
# 2
# 8
# (2, 4)
# int64
# [[0. 0.]
#  [0. 0.]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-f1e08fe0c9a5> in <cell line: 16>()
#      14 x1=np.zeros((2,2))
#      15 print(x1)
# ---> 16 x2=np.random(4)
#      17 print(x2)
#
# TypeError: 'module' object is not callable

# %%
import numpy as np
x3=np.array([1,2,3,4])
x4=np.array([2,3,4,5])
x5=x3+x4
x6=x3-x4
print("Add:",x5)
print("Sub:",x6)
# Out:
# Add: [3 5 7 9]
# Sub: [-1 -1 -1 -1]

# %%
import numpy as np
x1=[]
x=int(input('enter the number of elements:'))
for i in range(0,x):
  x=int(input())
  x1.append(x)
print(x1)

x2=[]
y=int(input('enter the number of elements:'))
for i in range(0,y):
  y=int(input())
  x2.append(y)
print(x2)
x3=[]

operation = 0
print('1:Addition')
print('2:Multiplication')
print(int(input('Enter the operation you want to perform:')))
if(operation == '1'):
  x3=np.add(x1,x2)
  print(x3)
elif(operation == '2'):
  x3=np.multiply(x1,x2)
  print(x3)
# Out:
# enter the number of elements:2
# 1
# 2
# [1, 2]
# enter the number of elements:2
# 1
# 2
# [1, 2]
# 1:Addition
# 2:Multiplication
# Enter the operation you want to perform:1
# 1

# %%
import numpy as np

x1=[]
x=int(input('enter the number of elements:'))
for i in range(0,x):
  x=int(input())
  x1.append(x)
print(x1)

x2=[]
y=int(input('enter the number of elements:'))
for i in range(0,y):
  y=int(input())
  x2.append(y)
print(x2)

x3=[]
print('1:Addition')
print('2:Multiplication')
print('3:Substraction')
print('4:Division')
z=int(input('Enter the operation you want to perform:'))

if(z == 1):
  x3=np.add(x1,x2)
  print(x3)

elif(z == 2):
  x3=np.multiply(x1,x2)
  print(x3)

elif(z ==3):
  x3=np.subtract(x1,x2)
  print(x3)

elif(z == 4):
  x3=np.divide(x1,x2)
  print(x3)

else:
  print('invalid choice')
# Out:
# enter the number of elements:2
# 1
# 2
# [1, 2]
# enter the number of elements:2
# 1
# 1
# [1, 1]
# 1:Addition
# 2:Multiplication
# 3:Substraction
# 4:Division
# Enter the operation you want to perform:1
# [2 3]

# %%
import numpy as np
x=[]
x1=int(input('enter the elements for 1st array:'))
for i in range(0,x1):
  x2=int(input())
  x.append(x2)
print(x)

y=[]
y1=int(input('enter the elements for 2nd array:'))
for i in range(0,y1):
  y2=int(input())
  y.append(y2)
print(y)

n=0
switch={
    1:'Add',
    2:'Sub',
    3:'Multiply',
    4:'Div',
}
return switch.get(n,'Invalid')
print(n(2))
# Out:
# enter the elements for 1st array:1
# 1
# [1]
# enter the elements for 2nd array:1
# 2
# [2]
#   File "<ipython-input-40-4ae812f6f3b5>", line 23
#     return switch.get(n,'Invalid')
#     ^
# SyntaxError: 'return' outside function

# %%
print("1. Add")
print("2. Subtract")
print("3. Multiply")
print("4. Divide")

choice = int(input("Enter your choice: "))

if choice == 1:
  print("Enter two numbers to add:")
  n1 = int(input())
  n2 = int(input())
  print('Result:',n1 + n2)

elif choice == 2:
  print("Enter two numbers to subtract:")
  n1 = int(input())
  n2 = int(input())
  print('Result:',n1 - n2)

elif choice == 3:
  print("Enter two numbers to multiply:")
  n1 = int(input())
  n2 = int(input())
  print('Result:',n1 * n2)

elif choice == 4:
  print("Enter two numbers to divide:")
  n1 = int(input())
  n2 = int(input())
  print('Result:',n1 / n2)

else:
  print("Invalid choice.")
# Out:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# Enter your choice: 2
# Enter two numbers to subtract:
# 6
# 9
# Result: -3

# %%
x=int(input('enter a number: '))
if(x>=0):
  print('number is positive')
elif(x<0):
  print('number is negative')
else:
  print('invalid')
# Out:
# enter a number: -5
# number if negative

# %%
def factorial(x):
  x=int(input('enter a number:'))
  fact=1
  for i in range(1,x+1):
    fact=fact*i
  print(fact)

# %%
factorial(x)
# Out:
# enter a number:3
# 6

# %%
a=1
b=2
c=3
if(a>b) & (a>c):
  print('a is greatest')
elif(b>a) & (b>c):
  print('b is greatest')
elif(c>a) & (c>b):
  print('c is greatest')
# Out:
# c is greatest

# %%
x=int(input('enter year:'))
if(x%4==0):
  print('its a leap year')
else:
  print('its not a leap year')
# Out:
# enter year:2024
# its a leap year

# %%
import numpy as np
x=np.array([[1,2,3,4],[5,6,7,8]])
print(np.shape(x))
# Out:
# (2, 4)

# %%
x='abcd,xyz'
y='ABC'
print(x.capitalize())
print(x.lower())
print(x.upper())
print(x.title())
print(x.swapcase())
# Out:
# Abcd,xyz
# abcd,xyz
# ABCD,XYZ
# Abcd,Xyz
# ABCD,XYZ

# %%
import numpy as np
import pandas as pd
data=np.array([2,4,6,8])
x=pd.Series(data)
print(x)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# dtype: int64

# %%
import pandas as pd
x=pd.Series([[1,2,3,4],[5,6,7,8]])
print(x)
# Out:
# 0    [1, 2, 3, 4]
# 1    [5, 6, 7, 8]
# dtype: object

# %%
import pandas as pd
x=pd.DataFrame([[1,2,3,4],[5,6,7,8]])
print(x)
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  5  6  7  8

# %%
import pandas as pd
x=pd.read_csv("TrainAndValid.csv")
print(x(head(5)))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-a8af03284546> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 x=pd.read_csv("TrainAndValid.csv")
#       3 print(x(head(5)))
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
import pandas as pd
x=pd.read_csv("test.txt")
print(x)
# Out:
#   test=abc
# 0    12345
# 1      xyz

# %%
import pandas as pd
import csv

with open("csv1.csv",mode='w') as csv_file:
  ind_writer=csv.writer(csv_file,delimiter=',')
  ind_writer.writerow([2022,'ne','inr','H20','FP'])
  ind_writer.writerow([2023,'ni','sgd','H21','FP1'])
#print(csv1.csv)

with open('csv1.csv',mode='r') as csv_file:
  csvfile=csv.reader(csv_file)
  for lines in csvfile:
    print(lines)
# Out:
# ['2022', 'ne', 'inr', 'H20', 'FP']
# ['2023', 'ni', 'sgd', 'H21', 'FP1']

# %%
import pandas as pd
x=pd.read_excel("Orders-With Nulls.xlsx")
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-746d1f3ba0c9> in <cell line: 3>()
#       1 import pandas as pd
#       2 x=pd.read_excel("Orders-With Nulls.xlsx")
# ----> 3 print(x(head(5)))
#
# NameError: name 'head' is not defined

# %%
import pandas as pd
dict={
    'Name':['abc','xyz'],
    'ID':['1','2'],
    'Age':['20','19']
}
x=pd.DataFrame(dict)
print(x)
# Out:
#   Name ID Age
# 0  abc  1  20
# 1  xyz  2  19

# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt

x=[2,4,6,8]
y=[6,8,9,12]
label=['a','b','c','d']
data=[10,20,30,40]

#plt.hist(x,y)
#plt.scatter(x,y)

#plt.plot(x,y,'o') # scatter
plt.pie(data,labels=label)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import csv
x=[]
y=[]
with open('csv1.csv','r')as csvfile:
  plots=csv.reader(csvfile,delimiter=',')
  for row in plots:
    x.append(row[0])
    y.append(row[2])
plt.bar(x,y,color='g')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('csv1.csv')

df = pd.DataFrame(data)

X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 1])

plt.bar(X, Y, color='g')
plt.title("Students over 11 Years")
plt.xlabel("Years")
plt.ylabel("Number of Students")
plt.show()
