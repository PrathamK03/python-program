# %%
pip install plotly

# %%
import plotly.express as px

# %%
import numpy as np
from IPython.display import HTML
init_notebook_mode(connected=True)
countries=['US','UK','UAE','SG']
fig=go.Figure([go.Bar(x=countries,y=[20,30,40,50])])
HTML(fig.to_html())
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import numpy as np
import plotly.express as px
from IPython.display import HTML
countries=['US','UK','UAE','SG']
ex=[20,30,40,50]
fig=px.pie(names=countries,values=ex,title='Pie chart')
HTML(fig.to_html())
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import plotly.express as px

# %%
import numpy as np
from IPython.display import HTML
import plotly.express as px
x=[0,1,2,3,4,5]
y=[0,5,6,7,8,9]
fig=px.scatter(x,y)
HTML(fig.to_html())
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from IPython.display import HTML
import plotly.express as px
df = px.data.iris()
display(df.head())
fig = px.scatter(df, x="sepal_width", y="sepal_length")
HTML(fig.to_html())
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import numpy as np
from IPython.display import HTML
import plotly.express as px
x=[0,1,2,3,4,5]
y=[0,5,6,7,8,9]
fig=px.line(x,y)
HTML(fig.to_html())
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import numpy as np
from IPython.display import HTML
import plotly.express as px
x=[0,1,2,3,4,5]
y=[0,5,6,7,8,9]
fig=px.histogram(x,y)
HTML(fig.to_html())
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import numpy as np
from IPython.display import HTML
import plotly.express as px
df=px.data.iris()
fig=px.scatter(df,x="sepal_length",y="petal_width")
HTML(fig.to_html())
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import numpy as np
from IPython.display import HTML
import plotly.express as px
df=px.data.iris()
fig=px.scatter(df,x="species",y="petal_width",size="petal_length",color="species")
HTML(fig.to_html())
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import numpy as np
from IPython.display import HTML
import plotly.express as px
df=px.data.iris()
fig=px.box(df,x="sepal_length",y="petal_width")
HTML(fig.to_html())
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import numpy as np
from IPython.display import HTML
import plotly.express as px
df=px.data.iris()
fig=px.violin(df,x="sepal_length",y="petal_width")
HTML(fig.to_html())
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import numpy as np
from IPython.display import HTML
import plotly.express as px
import plotly.figure_factory as ff
df=[dict(Task="jobA",Start='2020-1-1',Finish='2020-2-2'),dict(Task="jobB",Start='2020-3-3',Finish='2020-4-4'),dict(Task="jobC",Start='2020-5-5',Finish='2020-6-6')]
fig=ff.create_gantt(df)
HTML(fig.to_html())
# Out:
# Output hidden; open in https://colab.research.google.com to view.
