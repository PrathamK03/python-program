# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import sklearn

# %%
file=pd.read_csv("TrainAndValid.csv",low_memory=False)
file.head(10)
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246    66000.0     999089     3157         121           3.0      2004
# 1  1139248    57000.0     117657       77         121           3.0      1996
# 2  1139249    10000.0     434808     7009         121           3.0      2001
# 3  1139251    38500.0    1026470      332         121           3.0      2001
# 4  1139253    11000.0    1057373    17311         121           3.0      2007
# 5  1139255    26500.0    1001274     4605         121           3.0      2004
# 6  1139256    21000.0     772701     1937         121           3.0      1993
# 7  1139261    27000.0     902002     3539         121           3.0      2001
# 8  1139272    21500.0    1036251    36003         121           3.0      2008
# 9  1139275    65000.0    1016474     3883         121           3.0      1000
#
#    MachineHoursCurrentMeter UsageBand         saledate  ...  \
# ...

# %%
print(file.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412698 entries, 0 to 412697
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   object
#  9   saledate                  412698 non-null  object
#  10  fiModelDesc               412698 non-null  object
#  11  fiBaseModel               412698 non-null  object
#  12  fiSecondaryDesc           271971 non-null  object
# ...

# %%
print("the missing values in the dataset:")
file.isna().sum()
# Out:
# the missing values in the dataset:
# SalesID                          0
# SalePrice                        0
# MachineID                        0
# ModelID                          0
# datasource                       0
# auctioneerID                 20136
# YearMade                         0
# MachineHoursCurrentMeter    265194
# UsageBand                   339028
# saledate                         0
# fiModelDesc                      0
# fiBaseModel                      0
# fiSecondaryDesc             140727
# fiModelSeries               354031
# fiModelDescriptor           337882
# ProductSize                 216605
# fiProductClassDesc               0
# state                            0
# ProductGroup                     0
# ProductGroupDesc                 0
# Drive_System                305611
# Enclosure                      334
# Forks                       214983
# Pad_Type                    331602
# Ride_Control                259970
# Stick                       331602
# ...

# %%
plt.figure(figsize=(10, 6))
plt.scatter(file["saledate"][:1000], file["SalePrice"][:1000], color="salmon")
plt.xlabel('Sale Date')
plt.ylabel('Sale Price')
plt.title('Sale Price over Time')
plt.tight_layout()
plt.show()

# %%
file.SalePrice.plot.hist();

# %%
file["saledate"].head()
# Out:
# 0    11/16/2006 0:00
# 1     3/26/2004 0:00
# 2     2/26/2004 0:00
# 3     5/19/2011 0:00
# 4     7/23/2009 0:00
# Name: saledate, dtype: object

# %%
file["saledate"].dtype
# Out:
# dtype('O')

# %%
file = pd.read_csv("TrainAndValid.csv",low_memory=False, parse_dates=
file["saledate"].head()
# Out:
#   File "<ipython-input-26-87b6d507d1bd>", line 2
#     file["saledate"].head()
#                            ^
# SyntaxError: incomplete input

# %%
file["saledate"].head()
# Out:
# 0    11/16/2006 0:00
# 1     3/26/2004 0:00
# 2     2/26/2004 0:00
# 3     5/19/2011 0:00
# 4     7/23/2009 0:00
# Name: saledate, dtype: object

# %%
file["saledate"].dtype
# Out:
# dtype('O')

# %%
plt.figure(figsize=(10, 6))
plt.scatter(file["saledate"][:1000], file["SalePrice"][:1000], color="darksalmon
plt.xlabel('Sale Date')
plt.ylabel('Sale Price')
plt.title('Sale Price over Time')
plt.tight_layout()
plt.show()
# Out:
#   File "<ipython-input-27-72c39b72d63d>", line 2
#     plt.scatter(file["saledate"][:1000], file["SalePrice"][:1000], color="darksalmon
#                                                                          ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
file.head().T
# Out:
#                                                                  0  \
# SalesID                                                    1139246
# SalePrice                                                  66000.0
# MachineID                                                   999089
# ModelID                                                       3157
# datasource                                                     121
# auctioneerID                                                   3.0
# YearMade                                                      2004
# MachineHoursCurrentMeter                                      68.0
# UsageBand                                                      Low
# saledate                                           11/16/2006 0:00
# fiModelDesc                                                   521D
# fiBaseModel                                                    521
# fiSecondaryDesc                                                  D
# ...
