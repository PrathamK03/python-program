# %%
#creating a table
import pandas as pd
x={'rollnumber':[1,2,3,4,5],'name':["a","b","c","d","e"],'percentage':[70,75,80,65,80]}
myvar=pd.DataFrame(x)
print(myvar)
# Out:
#    rollnumber name  percentage
# 0           1    a          70
# 1           2    b          75
# 2           3    c          80
# 3           4    d          65
# 4           5    e          80

# %%
#assigning our own index
import pandas as pd
y=[1,2,3,4,5]
z=pd.Series(y,index=["a","b","c","d","e"])
print(z)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
print(myvar.loc[[0,2]])
# Out:
#    rollnumber name  percentage
# 0           1    a          70
# 2           3    c          80

# %%
print(z.loc[["d","a"]])
# Out:
# d    4
# a    1
# dtype: int64

# %%
import pandas as pd
df=pd.read_csv('industry.csv')
#print(df)
#df.head()
df.tail(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-4055afe098fc> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df=pd.read_csv('industry.csv')
#       3 #print(df)
#       4 #df.head()
#       5 df.tail(10)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
print(pd.options.display.max_rows)

# %%
print(df.info())

# %%
xyz=df.dropna()
print(xyz)
#print(df)

# %%
df.fillna('abc')

# %%
import pandas as pd
df=pd.read_csv('day.csv')
print(df)

# %%
print(df.info())

# %%
df.head(15)

# %%
df.tail(10)

# %%
import pandas as pd
df=pd.read_csv('continent.csv')
print(df)

# %%
print(df.shape)
#print(df.len)
print(df.describe)

# %%
print(df.info)

# %%
print(df.size)

# %%
df=pd.read_excel('emp.xlsx')
print(df)

# %%
df_sheet_index=pd.read_excel('emp.xlsx',sheet_name=0)
print(df_sheet_index)

# %%
df_1=pd.read_excel('emp.xlsx',sheet_name='Sheet 0')
print(df_1)

# %%
df_2=pd.read_excel('emp.xlsx',sheet_name='Sheet 1')
print(df_2)

# %%
df_3=pd.read_excel('emp.xlsx',sheet_name='Sheet 2')
print(df_3)

# %%
df_4=pd.read_excel('emp.xlsx',sheet_name=None)
print(df_4)

# %%
import pandas as pd
import openpyxl
df=pd.DataFrame([[10,20,30],[11,22,33],[12,23,34]],index=[1,2,3],columns=['a','b','c'])
print(df)

# %%
df.to_excel('emp1.xlsx',sheet_name='Sheet 0',index=[1,2,3],columns=['a','b','c'])

# %%
df_5=pd.read_excel('emp1.xlsx',sheet_name='Sheet 0')
print(df_5)

# %%
f=open("test1.txt","r")
print(f.readline())
print(f.readline())
f.close()
