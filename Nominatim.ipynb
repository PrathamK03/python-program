# %%
pip install phonenumbers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 19.6 MB/s eta 0:00:00
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
from geopy.extra.rate_limiter import RateLimiter

# %%
loc='Pune'
geolocator=Nominatim(user_agent='my_request')
location=geolocator.geocode(loc)
print(location.address)
print(location.latitude,location.longitude)
# Out:
# Pune City, Pune, Maharashtra, India
# 18.521428 73.8544541

# %%
geoloc=Nominatim(user_agent='Pune')
loc_name=geoloc.reverse("18.34,73.35")
print(loc_name.address)
# Out:
# Manjurne, Mangaon Taluka, Raigad, Maharashtra, India

# %%
loc=['Pune,Maharastra','Banglore,Karnataka','Mumbai,Maharastra','abcd,def']
df=pd.DataFrame({'add':loc})
geolocator=Nominatim(user_agent='my_request')
geocode=RateLimiter(geolocator.geocode,min_delay_seconds=5)
df['location']=df['add'].apply(geocode)
df['lat']=df['location'].apply(lambda x:x.latitude if x else None)
df['lon']=df['location'].apply(lambda x:x.longitude if x else None)
df
# Out:
#                   add                                           location  \
# 0     Pune,Maharastra  (Pune City, Pune, Maharashtra, India, (18.5214...
# 1  Banglore,Karnataka  (Government Hospital, Banglore, 1st Cross Road...
# 2   Mumbai,Maharastra  (Mumbai City, Maharashtra, India, (18.9733536,...
# 3            abcd,def                                               None
#
#          lat        lon
# 0  18.521428  73.854454
# 1  12.958746  77.557346
# 2  18.973354  72.828105
# 3        NaN        NaN

# %%
import phonenumbers
from phonenumbers import timezone
from phonenumbers import geocoder
from phonenumbers import carrier
number=input("enter phone number with country code:")
phonenumber=phonenumbers.parse(number)
tz=timezone.time_zones_for_number(phonenumber)
print("timezone:"+str(tz))
geoloc=geocoder.description_for_number(phonenumber,"en")
print("location:"+geoloc)
service=carrier.name_for_number(phonenumber,"en")
print("service provider:"+service)
# Out:
# enter phone number with country code:+91 9890915321
# timezone:('Asia/Calcutta',)
# location:India
# service provider:Airtel

# %%
pip install opencage

# %%
import folium
from opencage.geocoder import OpenCageGeocode
number=input("enter phone number with country code:")
phonenumber=phonenumbers.parse(number)
tz=timezone.time_zones_for_number(phonenumber)
print("timezone:"+str(tz))
geoloc=geocoder.description_for_number(phonenumber,"en")
print("location:"+geoloc)
key="e262d8a9fc864d4c85f5e7639c58c227"
geocoder=OpenCageGeocode(key)
query=str(geoloc)
results=geocoder.geocode(query)
service=carrier.name_for_number(phonenumber,"en")
print("service provider:"+service)
lat=results[0]['geometry']['lat']
lon=results[0]['geometry']['lon']
#lat=getLoc.latitude()
#lat=getLoc.longitude()
mymap=folium.Map(location=[lat,lon],zoom_start=5)
folium.Marker([lat,lon],popup=geoloc).add_to(myMap)
myMap.save("loc.html")
# Out:
# enter phone number with country code:+91 7030231071
# timezone:('Asia/Calcutta',)
# location:India
# ---------------------------------------------------------------------------
# NotAuthorizedError                        Traceback (most recent call last)
# <ipython-input-27-9e1a1d16f09e> in <cell line: 12>()
#      10 geocoder=OpenCageGeocode(key)
#      11 query=str(geoloc)
# ---> 12 results=geocoder.geocode(query)
#      13 service=carrier.name_for_number(phonenumber,"en")
#      14 print("service provider:"+service)
#
# /usr/local/lib/python3.10/dist-packages/opencage/geocoder.py in geocode(self, query, **kwargs)
#     193
#     194         request = self._parse_request(query, kwargs)
# --> 195         response = self._opencage_request(request)
#     196
#     197         return floatify_latlng(response['results'])
#
# /usr/local/lib/python3.10/dist-packages/backoff/_sync.py in retry(*args, **kwargs)
#     103
#     104             try:
# ...
