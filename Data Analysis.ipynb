# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('Titanic-Dataset.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data["Age"].fillna(30)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    30.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.shape
# Out:
# (891, 12)

# %%
data.size
# Out:
# 10692

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data["Age"].fillna(method='ffill',inplace=True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data["Cabin"].fillna(method='bfill',inplace=True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          1
# Embarked       2
# dtype: int64

# %%
data["Cabin"].fillna(method='ffill',inplace=True)

# %%
data["Embarked"].fillna(method='bfill',inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df1=pd.read_csv("Titanic-Dataset.csv")
df2=pd.read_csv("Titanic-Dataset1.csv")
df1.head()
df2.head()
cdata=pd.concat([df1,df2],ignore_index=True)
cdata
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1         0       3
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# ...           ...       ...     ...
# 1777          887         0       2
# 1778          888         1       1
# 1779          889         0       3
# 1780          890         1       1
# 1781          891         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df1.shape
# Out:
# (891, 12)

# %%
df2.shape
# Out:
# (891, 12)

# %%
cdata.shape
# Out:
# (1782, 12)

# %%
mdata=pd.merge(df1,df2)
mdata
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1=pd.read_csv("Book1.csv")
df2=pd.read_csv("Book2.csv")

# %%
df1
# Out:
#    RollNo Name  Age  Phone        Email Address
# 0       1    a   19   1234  a@gmail.com    abcd
# 1       2    b   20   6544  b@gmail.com    jdge
# 2       3    c   21   8765  c@gmail.com    kfhe
# 3       4    d   22   9665  d@gmail.com    kwhf
# 4       5    e   23   3245  e@gmail.com    lfke

# %%
df2
# Out:
#    RollNo Name  M1  M2  M3  M4  M5  Total
# 0       1    a  86  98  56  87  80    407
# 1       2    b  56  67  47  65  67    302
# 2       3    c  34  87  34  49  68    272
# 3       4    d  76  65  87  50  50    328
# 4       5    e  45  45  65  60  49    264

# %%
cdata=pd.concat([df1,df2],ignore_index=True)
cdata
# Out:
#    RollNo Name   Age   Phone        Email Address    M1    M2    M3    M4  \
# 0       1    a  19.0  1234.0  a@gmail.com    abcd   NaN   NaN   NaN   NaN
# 1       2    b  20.0  6544.0  b@gmail.com    jdge   NaN   NaN   NaN   NaN
# 2       3    c  21.0  8765.0  c@gmail.com    kfhe   NaN   NaN   NaN   NaN
# 3       4    d  22.0  9665.0  d@gmail.com    kwhf   NaN   NaN   NaN   NaN
# 4       5    e  23.0  3245.0  e@gmail.com    lfke   NaN   NaN   NaN   NaN
# 5       1    a   NaN     NaN          NaN     NaN  86.0  98.0  56.0  87.0
# 6       2    b   NaN     NaN          NaN     NaN  56.0  67.0  47.0  65.0
# 7       3    c   NaN     NaN          NaN     NaN  34.0  87.0  34.0  49.0
# 8       4    d   NaN     NaN          NaN     NaN  76.0  65.0  87.0  50.0
# 9       5    e   NaN     NaN          NaN     NaN  45.0  45.0  65.0  60.0
#
#      M5  Total
# 0   NaN    NaN
# 1   NaN    NaN
# 2   NaN    NaN
# 3   NaN    NaN
# 4   NaN    NaN
# 5  80.0  407.0
# 6  67.0  302.0
# 7  68.0  272.0
# ...

# %%
mdata=pd.merge(df1,df2)
mdata
# Out:
#    RollNo Name  Age  Phone        Email Address  M1  M2  M3  M4  M5  Total
# 0       1    a   19   1234  a@gmail.com    abcd  86  98  56  87  80    407
# 1       2    b   20   6544  b@gmail.com    jdge  56  67  47  65  67    302
# 2       3    c   21   8765  c@gmail.com    kfhe  34  87  34  49  68    272
# 3       4    d   22   9665  d@gmail.com    kwhf  76  65  87  50  50    328
# 4       5    e   23   3245  e@gmail.com    lfke  45  45  65  60  49    264

# %%
# Method-1:
#mdata.drop(["Phone","Email","Address"],axis=1)

# Method-2:
#mdata.drop(mdata.iloc[:,4:6],axis=1,inplace=True)
#mdata
# Out:
#    RollNo Name  Age  Phone  M3  M4  M5  Total
# 0       1    a   19   1234  56  87  80    407
# 1       2    b   20   6544  47  65  67    302
# 2       3    c   21   8765  34  49  68    272
# 3       4    d   22   9665  87  50  50    328
# 4       5    e   23   3245  65  60  49    264

# %%
with open('DWSample2-TXT.txt')as fp:
  data=fp.read()
with open('DWSample3-TXT.txt')as fp:
  data1=fp.read()
data +="\n"
data+=data1
with open('text.txt','w')as fp:
  fp.write(data)
