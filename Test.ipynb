# %%
import numpy as np
x1=np.array([[1,1,1,1],[2,2,2,2]])
print(x1)
print("Dimentions:",x1.ndim)
print("Shape:",x1.shape)
print("Size:",x1.size)
print("Data Type:",x1.dtype)
# Out:
# [[1 1 1 1]
#  [2 2 2 2]]
# Dimentions: 2
# Shape: (2, 4)
# Size: 8
# Data Type: int64

# %%
import pandas as pd
x2={'id':[1,2,3,4],'name':['a','b','c','d'],'age':[19,20,21,22]}
x3=pd.DataFrame(x2)
print(x3)
# Out:
#    id name  age
# 0   1    a   19
# 1   2    b   20
# 2   3    c   21
# 3   4    d   22

# %%
import numpy as np
import matplotlib.pyplot as plt
x4=np.array([1,2,3,4])
x5=np.array([2,4,6,8])
plt.title("Graph")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.grid()
plt.plot(x4,x5,color="red")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x6={'ID':[1,2,3,4],'Name':['a','b','c','d']}
df=pd.DataFrame(data=x6)
df.plot.scatter(x='ID',y='Name')
plt.title('Graph')
# Out:
# Text(0.5, 1.0, 'Graph')

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.DataFrame({'Name':['a','b','b','c','c','c','d','d','d','d'],'ID':[1,2,2,3,3,3,4,4,4,4]})
df.groupby(['Name']).sum().plot(kind='pie',y='ID',autopct='%1.0f%%')
# Out:
# <Axes: ylabel='ID'>

# %%
from sklearn.datasets import load_iris
iris = load_iris()
X = iris.data
y = iris.target
feature_names = iris.feature_names
target_names = iris.target_names
print("Feature names:", feature_names)
print("Target names:", target_names)
print("\nFirst 10 rows of X:\n", X[:10])
# Out:
# Feature names: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Target names: ['setosa' 'versicolor' 'virginica']
#
# First 10 rows of X:
#  [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]]

# %%
from sklearn.datasets import load_iris
iris = load_iris()
#print (iris)
X = iris.data
y = iris.target
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split
 (X, y, test_size = 0.3, random_state = 1)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
#   File "<ipython-input-2-ff7f4af5cc57>", line 8
#     (X, y, test_size = 0.3, random_state = 1)
#     ^
# IndentationError: unexpected indent

# %%
from sklearn.datasets import load_iris
iris = load_iris()
X = iris.data
y = iris.target
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
 X, y, test_size = 0.4, random_state=2
)
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
classifier_knn = KNeighborsClassifier(n_neighbors = 3)
classifier_knn.fit(X_train, y_train)
y_pred = classifier_knn.predict(X_test)
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9666666666666667

# %%
import numpy as np
from sklearn import preprocessing
input_data = np.array([
   [2.1, -1.9, 5.5],
   [-1.5, 2.4, 3.5],
   [0.5, -7.9, 5.6],
   [5.9, 2.3, -5.8]])
print("Mean =", input_data.mean(axis=0))
print("Stddeviation = ", input_data.std(axis=0))
