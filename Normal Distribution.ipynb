# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

dataset = np.array([1, 2, 3, 4, 5, 6.6, 7.7])
sci = sp.stats.skew(dataset, bias=True)

plt.bar([0], [sci])
plt.xlabel("Dataset")
plt.ylabel("Skewness")
plt.title("Skewness of the Dataset")
plt.show()

# %%
from scipy.stats import binom
import matplotlib.pyplot as plt

ntrials = 10
t_prob = 0.5
probs = [binom.pmf(i,ntrials,t_prob)for i in range(11)]
plt.stem(list(range(11)),probs)
# Out:
# <StemContainer object of 3 artists>

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
dataset = np.array([273,3552,9938,40,571,97])
ks=sp.stats.kurtosis(dataset,fisher=True,bias=True)

print("Kurtosis:",ks)
plt.bar([0],[ks])
plt.xlabel("Dataset")
plt.ylabel("Kurtosis")
plt.title("Kurtosis of the Dataset")
plt.ylim(-0.5,0.5)
plt.show()
# Out:
# Kurtosis: 0.35199118141730557

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

mu=0
std=1
snd=stats.norm(mu,std)
x=np.linspace(-54,27,100)
plt.figure(figsize=(10,10))
plt.plot(x,snd.pdf(x))
plt.xlim(-9,4)
plt.title("Normal Distribution",fontsize='15')
plt.xlabel("Values of Random Variable X",fontsize='15')
plt.ylabel("Probability",fontsize='15')
plt.show()
