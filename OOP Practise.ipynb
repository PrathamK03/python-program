# %%
class book:
  def __init__(self,title,page):
    self.title=title
    self.page=page
  def __repr__(self):
    return f'the title of the book is {self.title} and the no of pages of the book is {self.page}'
x=book('xyz',200)
print(x)
# Out:
# the title of the book is xyz and the no of pages of the book is 200

# %%
class book1:
  def __init__(self,title,author,page):
    self.title=title
    self.author=author
    self.page=page

  def __repr__(self):
    return f"title:{self.title},author:{self.author},page: {self.page}"
x="xyz,200"
print(x)
class bird:
  def p(self):
    print('printed text')
a=bird()
a.p()
# Out:
# xyz,200
# printed text

# %%
# parent
class book2:
  def __init__(self,title,page):
    self.title=title
    self.page=page
    self.__price=1002
  def get_price(self):
    return self.__price
  def details(self):
    return f'title: {self.title} pages: {self.page} price: {self.get_price()}'


# child
class book3(book2):
  def __init__(self,title,page,author,genre):
    self.author=author
    self.genre=genre
    book2.__init__(self,title,page)

  def show(self):
    return f'title: {self.title} pages: {self.page} author: {self.author} genre: {self.genre} price: {self.get_price()}'



class bird(book3):
  def __init__(self,title,page,author,genre):
    book3.__init__(self,title,page,author,genre)
    #self.price=price
  def show(self):
    return f'title: {self.title} pages: {self.page} author: {self.author} genre: {self.genre}'

#a=bird('abc',111,'awer','dd')
#a.show()
a=book3('xyz',100,'abc','abcd')
a.show()
# Out:
# 'title: xyz pages: 100 author: abc genre: abcd price: 1002'
