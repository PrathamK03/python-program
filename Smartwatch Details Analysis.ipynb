# %%
 import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=pd.read_csv('Smart watch prices.csv')

# %%
x
# Out:
#         Brand           Model Operating System                Connectivity  \
# 0       Apple  Watch Series 7          watchOS  Bluetooth, Wi-Fi, Cellular
# 1     Samsung  Galaxy Watch 4          Wear OS  Bluetooth, Wi-Fi, Cellular
# 2      Garmin          Venu 2        Garmin OS            Bluetooth, Wi-Fi
# 3      Fitbit         Versa 3        Fitbit OS            Bluetooth, Wi-Fi
# 4      Fossil           Gen 6          Wear OS            Bluetooth, Wi-Fi
# ..        ...             ...              ...                         ...
# 374  Withings       ScanWatch      Withings OS            Bluetooth, Wi-Fi
# 375      Zepp               Z          Zepp OS  Bluetooth, Wi-Fi, Cellular
# 376     Honor    Watch GS Pro          Lite OS            Bluetooth, Wi-Fi
# 377      Oppo      Watch Free          ColorOS            Bluetooth, Wi-Fi
# 378  TicWatch           Pro 3          Wear OS  Bluetooth, Wi-Fi, Cellular
#
# ...

# %%
x.head(15)
# Out:
#        Brand               Model Operating System                Connectivity  \
# 0      Apple      Watch Series 7          watchOS  Bluetooth, Wi-Fi, Cellular
# 1    Samsung      Galaxy Watch 4          Wear OS  Bluetooth, Wi-Fi, Cellular
# 2     Garmin              Venu 2        Garmin OS            Bluetooth, Wi-Fi
# 3     Fitbit             Versa 3        Fitbit OS            Bluetooth, Wi-Fi
# 4     Fossil               Gen 6          Wear OS            Bluetooth, Wi-Fi
# 5     Huawei         Watch 3 Pro        HarmonyOS  Bluetooth, Wi-Fi, Cellular
# 6   TicWatch                  E3          Wear OS  Bluetooth, Wi-Fi, Cellular
# 7       Oppo             Watch 2          ColorOS            Bluetooth, Wi-Fi
# 8    Amazfit               GTR 3       Amazfit OS            Bluetooth, Wi-Fi
# 9     Skagen      Jorn Hybrid HR              NaN                   Bluetooth
# 10  Withings           ScanWatch      Withings OS                   Bluetooth
# ...

# %%
x.tail(10)
# Out:
#             Brand              Model Operating System  \
# 369        Xiaomi   Mi Watch Revolve   Proprietary OS
# 370        Skagen          Falster 3          Wear OS
# 371  Michael Kors  Access Bradshaw 2          Wear OS
# 372         Casio  G-Shock GSW-H1000          Wear OS
# 373        Mobvoi        TicWatch E3          Wear OS
# 374      Withings          ScanWatch      Withings OS
# 375          Zepp                  Z          Zepp OS
# 376         Honor       Watch GS Pro          Lite OS
# 377          Oppo         Watch Free          ColorOS
# 378      TicWatch              Pro 3          Wear OS
#
#                    Connectivity Display Type  Display Size (inches)  \
# 369            Bluetooth, Wi-Fi       AMOLED                   1.39
# 370            Bluetooth, Wi-Fi         OLED                   1.30
# 371            Bluetooth, Wi-Fi       AMOLED                   1.28
# 372            Bluetooth, Wi-Fi          LCD                   1.20
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 379 entries, 0 to 378
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Brand                      378 non-null    object
#  1   Model                      378 non-null    object
#  2   Operating System           376 non-null    object
#  3   Connectivity               378 non-null    object
#  4   Display Type               377 non-null    object
#  5   Display Size (inches)      376 non-null    float64
#  6   Resolution                 375 non-null    object
#  7   Water Resistance (meters)  378 non-null    object
#  8   Battery Life (days)        378 non-null    object
#  9   Heart Rate Monitor         378 non-null    object
#  10  GPS                        378 non-null    object
#  11  NFC                        378 non-null    object
#  12  Price (USD)                378 non-null    object
# dtypes: float64(1), object(12)
# ...

# %%
x.describe()
# Out:
#        Display Size (inches)
# count             376.000000
# mean                1.363165
# std                 0.218986
# min                 0.900000
# 25%                 1.200000
# 50%                 1.390000
# 75%                 1.400000
# max                 4.010000

# %%
x.isnull()
# Out:
#      Brand  Model  Operating System  Connectivity  Display Type  \
# 0    False  False             False         False         False
# 1    False  False             False         False         False
# 2    False  False             False         False         False
# 3    False  False             False         False         False
# 4    False  False             False         False         False
# ..     ...    ...               ...           ...           ...
# 374  False  False             False         False         False
# 375  False  False             False         False         False
# 376  False  False             False         False         False
# 377  False  False             False         False         False
# 378  False  False             False         False         False
#
#      Display Size (inches)  Resolution  Water Resistance (meters)  \
# 0                    False       False                      False
# ...

# %%
x.isnull().sum()
# Out:
# Brand                        1
# Model                        1
# Operating System             3
# Connectivity                 1
# Display Type                 2
# Display Size (inches)        3
# Resolution                   4
# Water Resistance (meters)    1
# Battery Life (days)          1
# Heart Rate Monitor           1
# GPS                          1
# NFC                          1
# Price (USD)                  1
# dtype: int64

# %%
x.shape
# Out:
# (379, 13)

# %%
x.size
# Out:
# 4927

# %%
x
# Out:
#         Brand           Model Operating System                Connectivity  \
# 0       Apple  Watch Series 7          watchOS  Bluetooth, Wi-Fi, Cellular
# 1     Samsung  Galaxy Watch 4          Wear OS  Bluetooth, Wi-Fi, Cellular
# 2      Garmin          Venu 2        Garmin OS            Bluetooth, Wi-Fi
# 3      Fitbit         Versa 3        Fitbit OS            Bluetooth, Wi-Fi
# 4      Fossil           Gen 6          Wear OS            Bluetooth, Wi-Fi
# ..        ...             ...              ...                         ...
# 374  Withings       ScanWatch      Withings OS            Bluetooth, Wi-Fi
# 375      Zepp               Z          Zepp OS  Bluetooth, Wi-Fi, Cellular
# 376     Honor    Watch GS Pro          Lite OS            Bluetooth, Wi-Fi
# 377      Oppo      Watch Free          ColorOS            Bluetooth, Wi-Fi
# 378  TicWatch           Pro 3          Wear OS  Bluetooth, Wi-Fi, Cellular
#
# ...
